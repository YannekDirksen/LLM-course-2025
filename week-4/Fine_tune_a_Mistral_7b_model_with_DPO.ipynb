# %% [markdown]
# # Fine-tune a Mistral-7b model with DPO

# %%
# %pip install -q datasets trl peft bitsandbytes sentencepiece wandb

# %%
import sys
print(sys.executable)
# Out:
# c:\Users\Yannek Dirksen\Desktop\hallo jan\Uni\MA Semester 2\LLM\LLM-course-2025\.venv\Scripts\python.exe

# %%
import os
from dotenv import load_dotenv
load_dotenv()

import gc
import torch

import transformers
from transformers import (
    AutoModelForCausalLM,
    AutoTokenizer,
    TrainingArguments,
    BitsAndBytesConfig,
)
from datasets import load_dataset
from peft import LoraConfig, PeftModel, get_peft_model, prepare_model_for_kbit_training
from trl import DPOTrainer
import bitsandbytes as bnb
import wandb

hf_token = os.getenv("HUGGINGFACE_TOKEN")
wb_token = os.getenv("WANDB_API_KEY")

assert hf_token is not None, "HUGGINGFACE_TOKEN not set"
assert wb_token is not None, "WANDB_API_KEY not set"

wandb.login(key=wb_token)

model_name = "mistralai/Mistral-7B-Instruct-v0.3"
new_model = "DPO-Mistral-7B-Instruct-v0.3"
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 6
#       3 load_dotenv()
#       5 import gc
# ----> 6 import torch
#       8 import transformers
#       9 from transformers import (
#      10     AutoModelForCausalLM,
#      11     AutoTokenizer,
#      12     TrainingArguments,
#      13     BitsAndBytesConfig,
#      14 )
#
# File c:\Users\Yannek Dirksen\Desktop\hallo jan\Uni\MA Semester 2\LLM\LLM-course-2025\.venv\Lib\site-packages\torch\__init__.py:281
#     277                     raise err
#     279         kernel32.SetErrorMode(prev_error_mode)
# --> 281     _load_dll_libraries()
#     282     del _load_dll_libraries
#     285 def _get_cuda_dep_paths(path: str, lib_folder: str, lib_name: str) -> list[str]:
#     286     # Libraries can either be in
#     287     # path/nvidia/lib_folder/lib or
#     288     # path/nvidia/cuXX/lib (since CUDA 13.0) or
# ...

# %% [markdown]
# ## Format dataset

# %%
def chatml_format(example):
    # Format system
    if len(example['system']) > 0:
        message = {"role": "system", "content": example['system']}
        system = tokenizer.apply_chat_template([message], tokenize=False)
    else:
        system = ""

    # Format instruction
    message = {"role": "user", "content": example['question']}
    prompt = tokenizer.apply_chat_template([message], tokenize=False, add_generation_prompt=True)

    # Format chosen answer
    chosen = example['chosen'] + "<|im_end|>\n"

    # Format rejected answer
    rejected = example['rejected'] + "<|im_end|>\n"

    return {
        "prompt": system + prompt,
        "chosen": chosen,
        "rejected": rejected,
    }

# Load dataset
dataset = load_dataset("Intel/orca_dpo_pairs")['train'] # consider using just a subset of this

# Save columns
original_columns = dataset.column_names

# Tokenizer
tokenizer = AutoTokenizer.from_pretrained(model_name)
tokenizer.pad_token = tokenizer.eos_token
tokenizer.padding_side = "left"

# Format dataset
dataset = dataset.map(
    chatml_format,
    remove_columns=original_columns
)

# Print sample
dataset[1]

# %% [markdown]
# ## Train model with DPO

# %%
import gc, torch, os

# (Optional but helpful) better allocator for fragmentation
os.environ["PYTORCH_CUDA_ALLOC_CONF"] = "expandable_segments:True"

gc.collect()
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# %%
# LoRA configuration
peft_config = LoraConfig(
    r=16,
    lora_alpha=16,
    lora_dropout=0.05,
    bias="none",
    task_type="CAUSAL_LM",
    target_modules=["k_proj", "gate_proj", "v_proj", "up_proj", "q_proj", "o_proj", "down_proj"],
)

# 4-bit quantization config for T4
bnb_config = BitsAndBytesConfig(
    load_in_4bit=True,
    bnb_4bit_use_double_quant=True,
    bnb_4bit_compute_dtype=torch.float16,  # T4: fp16
    bnb_4bit_quant_type="nf4",
)

# Force entire quantized model onto GPU 0 (no CPU/disk offload)
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    quantization_config=bnb_config,
    device_map={"": 0},
    low_cpu_mem_usage=True,
)
model.config.use_cache = False

# %%
training_args = DPOConfig(
    per_device_train_batch_size=1,      # was 4
    gradient_accumulation_steps=16,     # keeps effective batch ~16
    gradient_checkpointing=True,

    learning_rate=5e-5,
    lr_scheduler_type="cosine",
    max_steps=200,
    save_strategy="no",
    logging_steps=1,
    output_dir=new_model,
    optim="paged_adamw_32bit",
    warmup_steps=50,

    # T4-friendly precision
    bf16=False,
    fp16=True,

    report_to="wandb",

    # DPO-specific sequence shortening (VERY important for memory)
    max_prompt_length=256,   # how long the prompt part can be
)

# %%
dpo_trainer = DPOTrainer(
    model=model,
    ref_model=None,          # important when using peft_config
    args=training_args,
    train_dataset=dataset,   # must have prompt / chosen / rejected fields
    peft_config=peft_config,
)

dpo_trainer.train()

# %% [markdown]
# ## Upload model

# %%
# Save artifacts
dpo_trainer.model.save_pretrained("final_checkpoint")
tokenizer.save_pretrained("final_checkpoint")

# Flush memory
del dpo_trainer, model, ref_model
gc.collect()
torch.cuda.empty_cache()

# Reload model in FP16 (instead of NF4)
base_model = AutoModelForCausalLM.from_pretrained(
    model_name,
    return_dict=True,
    torch_dtype=torch.float16,
)
tokenizer = AutoTokenizer.from_pretrained(model_name)

# Merge base model with the adapter
model = PeftModel.from_pretrained(base_model, "final_checkpoint")
model = model.merge_and_unload()

# Save model and tokenizer
model.save_pretrained(new_model)
tokenizer.save_pretrained(new_model)

# Push them to the HF Hub
model.push_to_hub(new_model, use_temp_dir=False, token=hf_token)
tokenizer.push_to_hub(new_model, use_temp_dir=False, token=hf_token)

# %% [markdown]
# ## Inference

# %%
# Format prompt
message = [
    {"role": "system", "content": "You are a helpful assistant chatbot."},
    {"role": "user", "content": "What is a Large Language Model?"}
]
tokenizer = AutoTokenizer.from_pretrained(new_model)
prompt = tokenizer.apply_chat_template(message, add_generation_prompt=True, tokenize=False)

# Create pipeline
pipeline = transformers.pipeline(
    "text-generation",
    model=new_model,
    tokenizer=tokenizer
)

# Generate text
sequences = pipeline(
    prompt,
    do_sample=True,
    temperature=0.7,
    top_p=0.9,
    num_return_sequences=1,
    max_length=200,
)
print(sequences[0]['generated_text'])
